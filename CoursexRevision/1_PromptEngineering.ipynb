# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a poetic translator."),
    ("human", "Translate to Spanish: Roses are red, violets are blue."),
    ("ai", "Las rosas son rojas, las violetas azules."),
    ("human", "Translate to Spanish: The sun is bright."),
])
# Out:
# Running cells with 'venv (Python 3.9.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/amit.k.bansal/Documents/TestProjects/langchainYoutube/venv/bin/python -m pip install ipykernel -U --force-reinstall'
