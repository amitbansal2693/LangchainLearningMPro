# %%
'''
✅ Common Steps (All OS)
Create a new folder
Open it in VS Code

Create a virtual environment:
python -m venv venv
===================
❗ Does every virtual environment require reinstallation?
✅ Yes — every time you create a new virtual environment (venv), it starts clean — without any libraries installed, except for:
pip
setuptools
So, if you're using LangChain or any libraries like openai, transformers, etc., you must reinstall them inside each venv.
================

🪟 Windows Instructions
Activate virtual environment
venv\Scripts\Activate

Create requirements.txt with packages like:
langchain
openai


Install packages
pip install -r requirements.txt

Verify LangChain installation
Example:python -c "import langchain; print(langchain.__version__)"

🍏 macOS/Linux Instructions
Activate virtual environment
source venv/bin/activate

5–7: Same as Windows
(install requirements and verify installation)

💡 Tip:
You can always deactivate the virtual environment using:
deactivate
Let me know if you want me to generate the sample requirements.txt file or create a .sh/.bat script for setup automation.

=================================================
✅ 1. Check if Virtual Environment is Activated

In your terminal, look at the command prompt:
(venv) your-user-name@your-machine folder %

If you see (venv) or similar at the beginning, it means the virtual environment is already active.


✅ 2. Check if You Have a Virtual Environment Folder
Look for a folder named venv/ (or any name you gave it).
If it exists and contains bin/ (macOS/Linux) or Scripts/ (Windows), then the virtual environment is already created.

=====================
✅ 3. Check Installed Packages Inside the venv
Once inside the virtual environment, run:
pip list

=====================
✅ 4. Check a Specific Package
pip show langchain
This shows the version, location, and dependencies.
If it says “Package not found,” then it’s not installed in your current environment.
=====================
✅ 5. Check LangChain in Python (Quick Test)
You can also test it directly:
python -c "import langchain; print(langchain.__version__)"
If it throws ModuleNotFoundError, it's not installed.

=====================
✅ How to Install All These Libraries in One Command
Here’s the combined pip install command based on the image:

pip install \
langchain \
langchain-core \
langchain-openai \
openai \
langchain-anthropic \
langchain-google-genai \
google-generativeai \
langchain-huggingface \
transformers \
huggingface-hub \
python-dotenv \
numpy \
scikit-learn


=====================
'''

c



#create folder
python -m venv venv
